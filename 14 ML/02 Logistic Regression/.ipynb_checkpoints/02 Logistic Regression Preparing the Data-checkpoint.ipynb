# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.set_style('whitegrid')

# %%
train = pd.read_csv('titanic_train.csv')
test = pd.read_csv('titanic_test.csv')

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
sns.heatmap(train.isnull(), yticklabels=False, cbar=False, cmap='viridis')  # For TRAIN

# %%
sns.heatmap(test.isnull(), yticklabels=False, cbar=False, cmap='viridis')  # For TEST

# %% [markdown]
# # Handling Missing Data

# %% [markdown]
# ### Imputing Age

# %%
# Here we can impute the age as Mean value. But we will try better approach.
# We will impute the age as Mean of Their Passenger Class.
# In order to get the mean we will use boxplot

plt.figure(figsize=(10,8))
sns.boxplot(x='Pclass', y='Age', data=train)

print('From this boxplot, we can see the people who were in 1st calss was higher in age.')
print('3rd class passengesr were mostly young')
print('It is quiet obious, becase it take times to become wealthy to travel in 1st class')
# Out:
# From this boxplot, we can see the people who were in 1st calss was higher in age.
# 3rd class passengesr were mostly young
# It is quiet obious, becase it take times to become wealthy to travel in 1st class

# %%
def impute_age(age_pclass):
    Age = age_pclass[0]
    Pclass = age_pclass[1]
    
    if pd.isnull(Age):
        if Pclass == 1:
            return 37
        elif Pclass == 2:
            return 29
        else:
            return 24
    else:
        return Age

# %%
train['Age'] = train[['Age', 'Pclass']].apply(impute_age, axis=1)

# %%
sns.heatmap(train.isnull())                                    # Train

# %%
test['Age'] = train[['Age', 'Pclass']].apply(impute_age, axis=1)  # For Test

# %%
sns.heatmap(test.isnull())                                      # Test

# %% [markdown]
# ### Droping the missing values

# %%
# Here in cabin column, There are too much missing values so we will just drop the whole column
train.drop('Cabin', axis=1, inplace=True)

# %%
test.drop('Cabin', axis=1, inplace=True)

# %%
sns.heatmap(train.isnull())                                        # Test

# %%
sns.heatmap(test.isnull())                                           # Test

# %%
# Ok so there is no any null value in Test dataset, But there is one in Train.
# so will use train.dropna() this will drop all tha rows containing null values.
# Because there is only one row which contains null value so it will only drop single row from Train

train.dropna(inplace=True)

# %%
sns.heatmap(train.isnull())                                                 # Train

# %% [markdown]
# ## Now we don't have any missing value in both Train and Test

# %% [markdown]
# # Creating Dummy Variables for Categorical Data

# %%
# Here Sex and Embarked columns should be included in Train dataset for our analysis, we cannot just drop them.
# Here our ML algo can't work with string type data. So we will create dummy variabls for the columns which we have to 
# use as inputs.

# %%
pd.get_dummies(train['Sex'])
# Out:
#      female  male
# 0         0     1
# 1         1     0
# 2         1     0
# 3         1     0
# 4         0     1
# ..      ...   ...
# 886       0     1
# 887       1     0
# 888       1     0
# 889       0     1
# 890       0     1
#
# [889 rows x 2 columns]

# %%
# There is a issue here. One column is perfect predictor of another column.
# This problem is known as multicollinearity.

# To avoid this we will drop the forst column

sex = pd.get_dummies(train['Sex'], drop_first=True)
sex
# Out:
#      male
# 0       1
# 1       0
# 2       0
# 3       0
# 4       1
# ..    ...
# 886     1
# 887     0
# 888     0
# 889     1
# 890     1
#
# [889 rows x 1 columns]

# %%
# Same for embarked
embarked = pd.get_dummies(train['Embarked'], drop_first=True)
embarked
# Out:
#      Q  S
# 0    0  1
# 1    0  0
# 2    0  1
# 3    0  1
# 4    0  1
# ..  .. ..
# 886  0  1
# 887  0  1
# 888  0  1
# 889  0  0
# 890  1  0
#
# [889 rows x 2 columns]

# %%
# Now we will concatinate the newly created dummy variables in dataset
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train = pd.concat([train, sex, embarked], axis=1)
# Here we havn't changed the train dataset. We have just concatinated 3 different datasets train, sex, embarked.
# Then saved this new dataset as train. We can change the name from train if we want to.

train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### We will do the same for test dataset also

# %%
sex = pd.get_dummies(test['Sex'], drop_first=True)
embark = pd.get_dummies(test['Embarked'], drop_first=True)
test = pd.concat([test, sex, embark], axis=1)

# %%
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Embarked  male  \
# ...

# %% [markdown]
# # Droping all non - usefull columns

# %%
train.drop(['PassengerId', 'Name', 'Sex', 'Ticket', 'Embarked'], axis=1, inplace=True)

# %%
train
# Out:
#      Survived  Pclass   Age  SibSp  Parch     Fare  male  Q  S  male  Q  S
# 0           0       3  22.0      1      0   7.2500     1  0  1     1  0  1
# 1           1       1  38.0      1      0  71.2833     0  0  0     0  0  0
# 2           1       3  26.0      0      0   7.9250     0  0  1     0  0  1
# 3           1       1  35.0      1      0  53.1000     0  0  1     0  0  1
# 4           0       3  35.0      0      0   8.0500     1  0  1     1  0  1
# ..        ...     ...   ...    ...    ...      ...   ... .. ..   ... .. ..
# 886         0       2  27.0      0      0  13.0000     1  0  1     1  0  1
# 887         1       1  19.0      0      0  30.0000     0  0  1     0  0  1
# 888         0       3  24.0      1      2  23.4500     0  0  1     0  0  1
# 889         1       1  26.0      0      0  30.0000     1  0  0     1  0  0
# 890         0       3  32.0      0      0   7.7500     1  1  0     1  1  0
#
# [889 rows x 12 columns]

# %%
test.head(2)
# Out:
#    PassengerId  Pclass                              Name     Sex   Age  SibSp  \
# 0          892       3                  Kelly, Mr. James    male  22.0      0
# 1          893       3  Wilkes, Mrs. James (Ellen Needs)  female  38.0      1
#
#    Parch  Ticket    Fare Embarked  male  Q  S
# 0      0  330911  7.8292        Q     1  1  0
# 1      0  363272  7.0000        S     0  0  1

# %%
# same for test
test.drop(['PassengerId', 'Name', 'Sex', 'Ticket', 'Embarked'], axis=1, inplace=True)

# %%
test
# Out:
#      Pclass   Age  SibSp  Parch      Fare  male  Q  S
# 0         3  22.0      0      0    7.8292     1  1  0
# 1         3  38.0      1      0    7.0000     0  0  1
# 2         2  26.0      0      0    9.6875     1  1  0
# 3         3  35.0      0      0    8.6625     1  0  1
# 4         3  35.0      1      1   12.2875     0  0  1
# ..      ...   ...    ...    ...       ...   ... .. ..
# 413       3  29.0      0      0    8.0500     1  0  1
# 414       1  44.0      0      0  108.9000     0  0  0
# 415       3  24.0      0      0    7.2500     1  0  1
# 416       3  34.0      0      0    8.0500     1  0  1
# 417       3  18.0      1      1   22.3583     1  0  0
#
# [418 rows x 8 columns]

# %% [markdown]
# Here Pclass is also an categorical data with values 1,2 and 3, Means we can create it's dummy variables also.
# But we will leave it like that for now and apply ML model on this dataset.
# After applying the ML model. We will change the Pclass to dummy variables and then again apply the ML model on it.
# Then we can see how a model behave with new and old datasets.

# %% [markdown]
# # That's It. Well Done!!!!!
