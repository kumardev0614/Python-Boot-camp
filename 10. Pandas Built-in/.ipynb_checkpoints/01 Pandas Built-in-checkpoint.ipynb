# %%
import numpy as np
import seaborn as sns
import pandas as pd
# %matplotlib inline

sns.set_style('darkgrid')

# %%
df1 = pd.read_csv('df1.csv', index_col=0)
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2.csv')
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %% [markdown]
# # df.['colname'].hist()

# %%
df1['A'].hist(bins=30)

# %%
# aternative way
df1['A'].plot(kind='hist', bins=30)

# %%
# Recommanded way
df1['A'].plot.hist(bins=30)

# %%
df2
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008
# 5  0.286043  0.593465  0.907307  0.637898
# 6  0.430436  0.166230  0.469383  0.497701
# 7  0.312296  0.502823  0.806609  0.850519
# 8  0.187765  0.997075  0.895955  0.530390
# 9  0.908162  0.232726  0.414138  0.432007

# %%
# Area plot
df2.plot.area(alpha=0.4)

# %%
# BAR plot

df2.plot.bar()

# %%
df2.plot.bar(stacked=True)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
# Line plot

# df2.plot.line(x=[df2.index], y='a')

# %%
# Scatter

df1.plot.scatter(x= 'A', y='B')

# %%
df1.plot.scatter(x= 'A', y='B', c='D', cmap='coolwarm')

# %%
df1.plot.scatter(x= 'A', y='B', s=df1['C']*100)
# Out:
# C:\Users\BabaJi\anaconda3\lib\site-packages\matplotlib\collections.py:857: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
# Box Plot

df2.plot.box()

# %%
# Hexbin

df = pd.DataFrame(np.random.randn(1000,2), columns=['a','b'])

# %%
df
# Out:
#             a         b
# 0   -1.249700  2.175559
# 1   -0.036838 -0.821348
# 2    1.461948  0.345786
# 3   -0.011803 -1.359176
# 4   -1.217976  1.706924
# ..        ...       ...
# 995  1.293150  1.652648
# 996 -0.858947  1.143835
# 997  1.326970 -1.575267
# 998 -0.241506  0.795883
# 999 -1.173710  0.427114
#
# [1000 rows x 2 columns]

# %%
df.plot.hexbin(x='a', y='b', gridsize=25, figsize=(12,8))

# %%
# Kdeplot

df1['A'].plot.kde()

# %%
df1['A'].plot.density()

# %%
df1.plot.kde()

# %%
df2.plot.kde()
